# %%
# Obaid Ur Rehman

# %%
# %matplotlib inline

# %%
import pandas as pd  #importing pandas
import numpy as np
import matplotlib

# %% [markdown]
# # 1. Load the dataset to pandas dataframe and print names of columns¶
# output: ['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'class']

# %%
ckdf = pd.read_csv("Assignment Material/Dataset/chronic_kidney_disease_updated.csv")

# %%
ckdf[['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'class']]
# Out:
#      age   bp     sg   al   su       rbc        pc         pcc          ba  \
# 0    NaN  NaN    NaN  NaN  NaN       NaN       NaN         NaN         NaN
# 1     48   80  1.020    1    0         ?    normal  notpresent  notpresent
# 2      7   50  1.020    4    0         ?    normal  notpresent  notpresent
# 3     62   80  1.010    2    3    normal    normal  notpresent  notpresent
# 4     48   70  1.005    4    0    normal  abnormal     present  notpresent
# 5     51   80  1.010    2    0    normal    normal  notpresent  notpresent
# 6     60   90  1.015    3    0         ?         ?  notpresent  notpresent
# 7     68   70  1.010    0    0         ?    normal  notpresent  notpresent
# 8     24    ?  1.015    2    4    normal  abnormal  notpresent  notpresent
# 9     52  100  1.015    3    0    normal  abnormal     present  notpresent
# 10    53   90  1.020    2    0  abnormal  abnormal     present  notpresent
# ...

# %% [markdown]
# Printed columns: ['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'class']

# %% [markdown]
# # 2. Display first 5 rows in the dataset.

# %%
ckdf[1:6] #first five rows
# Out:
#   age  bp     sg al su     rbc        pc         pcc          ba  bgr  ...   \
# 1  48  80  1.020  1  0       ?    normal  notpresent  notpresent  121  ...
# 2   7  50  1.020  4  0       ?    normal  notpresent  notpresent    ?  ...
# 3  62  80  1.010  2  3  normal    normal  notpresent  notpresent  423  ...
# 4  48  70  1.005  4  0  normal  abnormal     present  notpresent  117  ...
# 5  51  80  1.010  2  0  normal    normal  notpresent  notpresent  106  ...
#
#   pcv  wbcc rbcc  htn   dm cad appet   pe  ane class
# 1  44  7800  5.2  yes  yes  no  good   no   no   ckd
# 2  38  6000    ?   no   no  no  good   no   no   ckd
# 3  31  7500    ?   no  yes  no  poor   no  yes   ckd
# 4  32  6700  3.9  yes   no  no  poor  yes  yes   ckd
# 5  35  7300  4.6   no   no  no  good   no   no   ckd
#
# [5 rows x 25 columns]

# %% [markdown]
# # 3. Check if dataset is in cleaned form else clean it. Check Diabetes Mellitus(dm) variable and print what type of values it has.

# %%
ckdf.dm.unique() #to check unique values.
# Out:
# array([nan, 'yes', 'no', ' yes', '\tno', '\tyes', '?'], dtype=object)

# %% [markdown]
# There is an abnormal value "?", so the dataset is not clean.

# %%
ckdf.dm.count()-(len(ckdf[ckdf.dm =='yes'])+len(ckdf[ckdf.dm =='no'])) #No of entries other than 'yes' or 'no'
# Out:
# 8

# %% [markdown]
#  Formula Used = totalCount of dm col - {(count of dm 'yes')+(count of dm 'no')}

# %%
#Proving that there is only one abnormal value.  Formula Used = totalCount of dm col - {(count of dm 'yes')+(count of dm 'no')}

# %%
ckdf.groupby('dm').dm.count()
# Out:
# dm
# \tno       3
# \tyes      2
#  yes       1
# ?          2
# no       258
# yes      134
# Name: dm, dtype: int64

# %% [markdown]
# # 4. The dataset is not in clean form. Write a function that takes pandas dataframe as an input and replace these characters i-e ( "\t", " ", "?") with "nan" and again check unique values of Diabetes Mellitus(dm)

# %%
def cleanData():
    for col in ckdf.columns.values:
        ckdf[col] = ckdf[col].replace('\t|\\t|\s|[?]', '', regex=True)
        ckdf[col] = ckdf[col].replace('', np.nan, regex=True)
            
cleanData() # will need this for Q.5

# %%
ckdf.groupby('dm').dm.count() #Proving there is no "?" occurance as there was before
# Out:
# dm
# no     261
# yes    137
# Name: dm, dtype: int64

# %%
ckdf.dm.unique() # Can also check using this command ("?yes" has been removed)
# Out:
# array([nan, 'yes', 'no'], dtype=object)

# %% [markdown]
# # 5. Change datatype to Numerical of following columns in Dataframe. columns = ['age', 'bp', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']

# %%
ckdf[['age', 'bp', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']]= ckdf[['age', 'bp', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']].astype(float)

# %%
ckdf.columns.to_series().groupby(ckdf.dtypes).groups
# Out:
# {dtype('float64'): Index([u'age', u'bp', u'bgr', u'bu', u'sc', u'sod', u'pot', u'hemo', u'pcv',
#         u'wbcc', u'rbcc'],
#        dtype='object'),
#  dtype('O'): Index([u'sg', u'al', u'su', u'rbc', u'pc', u'pcc', u'ba', u'htn', u'dm',
#         u'cad', u'appet', u'pe', u'ane', u'class'],
#        dtype='object')}

# %%
#Cannot convert NA values to Numerical therefore I used Float. Now there are two type of columns

# %% [markdown]
# # 6. Count the number of normal or abnormal red blood cells people having Chronic Kidney Disease(CKD).

# %%
ckdf.groupby('rbc').rbc.count() #displays the count
# Out:
# rbc
# abnormal     47
# normal      201
# Name: rbc, dtype: int64

# %%
data=ckdf.groupby('rbc').rbc.count().plot(kind="bar",figsize=(10, 5),title="Patients with Normal & Abnormal RBC") #grouped by rbc and thier count

# %% [markdown]
# # 7. Display maximum blood pressure having Chronic Kidney Disease(CKD).

# %%
data = ckdf.groupby('class')['bp'].max() 
print data
data.plot(kind="bar",figsize=(10, 5),title="Comparison of bp in ckd and non-ckd patients")
# Out:
# class
# ckd       180.0
# notckd     80.0
# Name: bp, dtype: float64

# %%
# The max blood presure for ckd in 180.0 and max blood pressure for notckd is 80.0

# %%
ckdf.loc[ckdf['class'].isin(['ckd'])]['bp'].max() # Command for highest blood pressure in all ckd patients.
# Out:
# 180.0

# %% [markdown]
# # 8. Create a csv file of cleaned data in dataframe with name "clean_chronic_kidney_disease.csv"

# %%
ckdf.to_csv('Assignment Material/Dataset/clean_chronic_kidney_disease.csv', sep=',')
