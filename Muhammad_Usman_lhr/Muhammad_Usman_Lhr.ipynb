# %%
print "Python Assignment 1 - DIH"
# Out:
# Python Assignment 1 - DIH

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib

# %%
# refrence:  http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html#pandas.read_csv
df=pd.read_csv("/resources/data/chronic_kidney_disease_updated.csv", sep=",")

# %%
# first five rows in dataset
df.head(5)
# Out:
#    age   bp     sg   al   su     rbc        pc         pcc          ba  bgr  \
# 0  NaN  NaN    NaN  NaN  NaN     NaN       NaN         NaN         NaN  NaN
# 1   48   80  1.020    1    0       ?    normal  notpresent  notpresent  121
# 2    7   50  1.020    4    0       ?    normal  notpresent  notpresent    ?
# 3   62   80  1.010    2    3  normal    normal  notpresent  notpresent  423
# 4   48   70  1.005    4    0  normal  abnormal     present  notpresent  117
#
#    ...   pcv  wbcc rbcc  htn   dm  cad appet   pe  ane class
# 0  ...   NaN   NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 1  ...    44  7800  5.2  yes  yes   no  good   no   no   ckd
# 2  ...    38  6000    ?   no   no   no  good   no   no   ckd
# 3  ...    31  7500    ?   no  yes   no  poor   no  yes   ckd
# 4  ...    32  6700  3.9  yes   no   no  poor  yes  yes   ckd
#
# [5 rows x 25 columns]

# %%
# names of columns
print df.columns.values
# Out:
# ['age' 'bp' 'sg' 'al' 'su' 'rbc' 'pc' 'pcc' 'ba' 'bgr' 'bu' 'sc' 'sod'
#  'pot' 'hemo' 'pcv' 'wbcc' 'rbcc' 'htn' 'dm' 'cad' 'appet' 'pe' 'ane'
#  'class']

# %%
# refrence:  http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.unique.html
# by checking the type of values in dm variable, it shows that data set is not clean
print df.dm.unique()
# Out:
# [nan 'yes' 'no' ' yes' '\tno' '\tyes' '?']

# %%
# refrence: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html#pandas.DataFrame.replace
df["dm"].replace(regex=True,inplace=True, to_replace=r'\t',value=r'')

# %%
# refrence: http://stackoverflow.com/questions/17097236/how-to-replace-values-with-none-in-pandas-data-frame-in-python
df.replace('0',np.nan)
# Out:
#      age   bp     sg   al   su       rbc        pc         pcc          ba  \
# 0    NaN  NaN    NaN  NaN  NaN       NaN       NaN         NaN         NaN
# 1     48   80  1.020    1  NaN         ?    normal  notpresent  notpresent
# 2      7   50  1.020    4  NaN         ?    normal  notpresent  notpresent
# 3     62   80  1.010    2    3    normal    normal  notpresent  notpresent
# 4     48   70  1.005    4  NaN    normal  abnormal     present  notpresent
# 5     51   80  1.010    2  NaN    normal    normal  notpresent  notpresent
# 6     60   90  1.015    3  NaN         ?         ?  notpresent  notpresent
# 7     68   70  1.010  NaN  NaN         ?    normal  notpresent  notpresent
# 8     24    ?  1.015    2    4    normal  abnormal  notpresent  notpresent
# 9     52  100  1.015    3  NaN    normal  abnormal     present  notpresent
# 10    53   90  1.020    2  NaN  abnormal  abnormal     present  notpresent
# ...

# %%
# to see the removed anomalies
print df.dm.unique()
# Out:
# [nan 'yes' 'no' ' yes' '?']

# %%
# refrence: http://stackoverflow.com/questions/17097236/how-to-replace-values-with-none-in-pandas-data-frame-in-python
# remove '?' from data frame
df=df.replace('\?',np.nan, regex=True)

# %%
print df.head()
# Out:
#    age   bp     sg   al   su     rbc        pc         pcc          ba  bgr  \
# 0  NaN  NaN    NaN  NaN  NaN     NaN       NaN         NaN         NaN  NaN
# 1   48   80  1.020    1    0     NaN    normal  notpresent  notpresent  121
# 2    7   50  1.020    4    0     NaN    normal  notpresent  notpresent  NaN
# 3   62   80  1.010    2    3  normal    normal  notpresent  notpresent  423
# 4   48   70  1.005    4    0  normal  abnormal     present  notpresent  117
#
#    ...   pcv  wbcc rbcc  htn   dm  cad appet   pe  ane class
# 0  ...   NaN   NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 1  ...    44  7800  5.2  yes  yes   no  good   no   no   ckd
# 2  ...    38  6000  NaN   no   no   no  good   no   no   ckd
# 3  ...    31  7500  NaN   no  yes   no  poor   no  yes   ckd
# 4  ...    32  6700  3.9  yes   no   no  poor  yes  yes   ckd
#
# [5 rows x 25 columns]

# %%
print df.dm.unique()
# Out:
# [nan 'yes' 'no' ' yes']

# %%
# change data type to numerical
# refrence: http://stackoverflow.com/questions/15891038/pandas-change-data-type-of-columns
df[['age','bp','bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']]= df[['age','bp','bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']].apply(pd.to_numeric, errors='ignore')

# %%
# to see the changed data types
print df.dtypes
# Out:
# age      float64
# bp       float64
# sg        object
# al        object
# su        object
# rbc       object
# pc        object
# pcc       object
# ba        object
# bgr      float64
# bu       float64
# sc       float64
# sod      float64
# pot      float64
# hemo     float64
# pcv      float64
# wbcc     float64
# rbcc     float64
# htn       object
# dm        object
# cad       object
# appet     object
# pe        object
# ane       object
# class     object
# dtype: object

# %%
# maximum blood pressure
print df['bp'].max()
# Out:
# 180.0

# %%
# refrence: http://stackoverflow.com/questions/19392226/attributeerror-dataframe-object-has-no-attribute
# Count the number of normal or abnormal red blood cells people having CKD
df['rbc'].value_counts()
# Out:
# normal      201
# abnormal     47
# Name: rbc, dtype: int64

# %%
# refrence: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_csv.html#pandas.DataFrame.to_csv
# csv file of cleaned data
df.to_csv("/resources/data/chronic_kidney_disease_updated.csv")
